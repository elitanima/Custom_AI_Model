# %% [markdown]
# <a href="https://colab.research.google.com/github/elitanima/Custom_AI_Model/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Fri Jan 23 12:06:42 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   36C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# Pip install method (recommended)

# !pip install ultralytics

from IPython import display
display.clear_output()

# prevent ultralytics from tracking your activity
# !yolo settings sync=False

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.4.7 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 38.9/112.6 GB disk)

# %%
# !pip install roboflow
# Out:
# Collecting roboflow
#   Downloading roboflow-1.2.12-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from roboflow) (2026.1.4)
# Collecting idna==3.7 (from roboflow)
#   Downloading idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: cycler in /usr/local/lib/python3.12/dist-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.4.9)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from roboflow) (3.10.0)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.12/dist-packages (from roboflow) (2.0.2)
# Collecting opencv-python-headless==4.10.0.84 (from roboflow)
#   Downloading opencv_python_headless-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from roboflow) (11.3.0)
# Collecting pi-heif<2 (from roboflow)
#   Downloading pi_heif-1.2.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.5 kB)
# Collecting pillow-avif-plugin<2 (from roboflow)
#   Downloading pillow_avif_plugin-1.5.5-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (2.2 kB)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.12/dist-packages (from roboflow) (2.9.0.post0)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.2.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from roboflow) (2.32.4)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.12/dist-packages (from roboflow) (2.5.0)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.12/dist-packages (from roboflow) (4.67.1)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from roboflow) (6.0.3)
# Requirement already satisfied: requests-toolbelt in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.0.0)
# Collecting filetype (from roboflow)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->roboflow) (1.3.3)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->roboflow) (4.61.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->roboflow) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->roboflow) (3.3.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->roboflow) (3.4.4)
# Downloading roboflow-1.2.12-py3-none-any.whl (91 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.7/91.7 kB 8.3 MB/s eta 0:00:00
# Downloading idna-3.7-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 7.2 MB/s eta 0:00:00
# Downloading opencv_python_headless-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 18.8 MB/s eta 0:00:00
# Downloading pi_heif-1.2.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 99.8 MB/s eta 0:00:00
# Downloading pillow_avif_plugin-1.5.5-cp312-cp312-manylinux_2_28_x86_64.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 153.2 MB/s eta 0:00:00
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Installing collected packages: pillow-avif-plugin, filetype, pi-heif, opencv-python-headless, idna, roboflow
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# Successfully installed filetype-1.2.0 idna-3.7 opencv-python-headless-4.10.0.84 pi-heif-1.2.0 pillow-avif-plugin-1.5.5 roboflow-1.2.12

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="Ключ")
project = rf.workspace("tets1-k0emt").project("project_test_1-qlnqb")
version = project.version(3)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in Project_Test_1-3 to yolov8:: 100%|██████████| 35500/35500 [00:03<00:00, 10728.46it/s]
# Extracting Dataset Version Zip to Project_Test_1-3 in yolov8:: 100%|██████████| 348/348 [00:00<00:00, 4037.79it/s]

# %%
# Удаляем всё разом
import shutil
shutil.rmtree('/content/datasets', ignore_errors=True)
shutil.rmtree('/content/Project_Test_1-1', ignore_errors=True)
shutil.rmtree('/content/Project_Test_1-3', ignore_errors=True)

print("✅ Всё удалено!")
# Out:
# ✅ Всё удалено!

# %%
import os
import shutil
import yaml
from pathlib import Path
from sklearn.model_selection import train_test_split

print("=" * 70)
print("📊 СОЗДАНИЕ TRAIN / VALID / TEST SPLITS")
print("=" * 70)

# Путь к датасету
dataset_path = '/content/Project_Test_1-3'
data_yaml = os.path.join(dataset_path, 'data.yaml')

# Проверяем текущую структуру
print("\n🔍 Текущая структура:")
train_img_dir = os.path.join(dataset_path, 'train', 'images')
train_lbl_dir = os.path.join(dataset_path, 'train', 'labels')

if not os.path.exists(train_img_dir):
    print("❌ Папка train/images не существует!")
    # Ищем где реально лежат файлы
    print("\n🔎 Поиск изображений...")
    for root, dirs, files in os.walk(dataset_path):
        images = [f for f in files if f.lower().endswith(('.jpg', '.png', '.jpeg'))]
        if images:
            print(f"   Найдено {len(images)} изображений в: {root}")
            train_img_dir = root
            # Предполагаем что labels рядом
            train_lbl_dir = root.replace('images', 'labels')
            if not os.path.exists(train_lbl_dir):
                train_lbl_dir = os.path.join(os.path.dirname(root), 'labels')
            break

# Получаем список всех изображений
all_images = [f for f in os.listdir(train_img_dir)
              if f.lower().endswith(('.jpg', '.png', '.jpeg'))]

print(f"\n📸 Найдено изображений: {len(all_images)}")

if len(all_images) == 0:
    print("❌ ОШИБКА: Нет изображений для разделения!")
    exit()

# ========================================
# РАЗДЕЛЕНИЕ: 70% train, 20% valid, 10% test
# ========================================
print("\n🔀 Разделение датасета...")
print("   📊 Train: 70%")
print("   📊 Valid: 20%")
print("   📊 Test:  10%")

# Сначала отделяем test (10%)
train_valid_imgs, test_imgs = train_test_split(
    all_images, test_size=0.10, random_state=42
)

# Потом из оставшихся делаем train/valid (70/20 от исходного)
train_imgs, valid_imgs = train_test_split(
    train_valid_imgs, test_size=0.222, random_state=42  # 0.222 * 0.9 ≈ 0.2
)

print(f"\n✅ Разделение выполнено:")
print(f"   Train: {len(train_imgs)} изображений ({len(train_imgs)/len(all_images)*100:.1f}%)")
print(f"   Valid: {len(valid_imgs)} изображений ({len(valid_imgs)/len(all_images)*100:.1f}%)")
print(f"   Test:  {len(test_imgs)} изображений ({len(test_imgs)/len(all_images)*100:.1f}%)")

# ========================================
# СОЗДАНИЕ ПАПОК
# ========================================
print("\n📁 Создание структуры папок...")

splits = {
    'train': train_imgs,
    'valid': valid_imgs,
    'test': test_imgs
}

for split_name, img_list in splits.items():
    # Создаем папки
    split_img_dir = os.path.join(dataset_path, split_name, 'images')
    split_lbl_dir = os.path.join(dataset_path, split_name, 'labels')

    os.makedirs(split_img_dir, exist_ok=True)
    os.makedirs(split_lbl_dir, exist_ok=True)

    print(f"   ✅ {split_name}/images")
    print(f"   ✅ {split_name}/labels")

# ========================================
# ПЕРЕМЕЩЕНИЕ ФАЙЛОВ
# ========================================
print("\n🚚 Перемещение файлов...")

# Сначала очищаем train (если там были все файлы)
temp_img_dir = os.path.join(dataset_path, '_temp_images')
temp_lbl_dir = os.path.join(dataset_path, '_temp_labels')

# Копируем все в temp
if os.path.exists(train_img_dir):
    shutil.copytree(train_img_dir, temp_img_dir, dirs_exist_ok=True)
if os.path.exists(train_lbl_dir):
    shutil.copytree(train_lbl_dir, temp_lbl_dir, dirs_exist_ok=True)

# Очищаем старые папки train
for folder in [train_img_dir, train_lbl_dir]:
    if os.path.exists(folder):
        shutil.rmtree(folder)
    os.makedirs(folder, exist_ok=True)

# Распределяем файлы
for split_name, img_list in splits.items():
    split_img_dir = os.path.join(dataset_path, split_name, 'images')
    split_lbl_dir = os.path.join(dataset_path, split_name, 'labels')

    for img_name in img_list:
        # Определяем имя label файла
        base_name = os.path.splitext(img_name)[0]
        lbl_name = base_name + '.txt'

        # Источники (из temp)
        src_img = os.path.join(temp_img_dir, img_name)
        src_lbl = os.path.join(temp_lbl_dir, lbl_name)

        # Назначения
        dst_img = os.path.join(split_img_dir, img_name)
        dst_lbl = os.path.join(split_lbl_dir, lbl_name)

        # Копируем
        if os.path.exists(src_img):
            shutil.copy2(src_img, dst_img)

        if os.path.exists(src_lbl):
            shutil.copy2(src_lbl, dst_lbl)

    print(f"   ✅ {split_name}: {len(img_list)} файлов перемещено")

# Удаляем temp папки
shutil.rmtree(temp_img_dir, ignore_errors=True)
shutil.rmtree(temp_lbl_dir, ignore_errors=True)

# ========================================
# ОБНОВЛЕНИЕ data.yaml
# ========================================
print("\n📝 Обновление data.yaml...")

with open(data_yaml, 'r') as f:
    config = yaml.safe_load(f)

# Обновляем пути
config['train'] = 'train/images'
config['val'] = 'valid/images'
config['test'] = 'test/images'

# Сохраняем
with open(data_yaml, 'w') as f:
    yaml.dump(config, f, default_flow_style=False, sort_keys=False)

print("   ✅ data.yaml обновлен")

# ========================================
# ФИНАЛЬНАЯ ПРОВЕРКА
# ========================================
print("\n" + "=" * 70)
print("✅ ИТОГОВАЯ СТРУКТУРА")
print("=" * 70)

print(f"\n📄 Конфигурация data.yaml:")
print(yaml.dump(config, default_flow_style=False, sort_keys=False))

print("\n📊 Статистика по splits:")
for split_name in ['train', 'valid', 'test']:
    img_dir = os.path.join(dataset_path, split_name, 'images')
    lbl_dir = os.path.join(dataset_path, split_name, 'labels')

    img_count = len([f for f in os.listdir(img_dir)
                    if f.lower().endswith(('.jpg', '.png', '.jpeg'))]) if os.path.exists(img_dir) else 0
    lbl_count = len([f for f in os.listdir(lbl_dir)
                    if f.lower().endswith('.txt')]) if os.path.exists(lbl_dir) else 0

    status = "✅" if img_count > 0 else "❌"
    print(f"{status} {split_name.upper():6} → Images: {img_count:4} | Labels: {lbl_count:4}")

# ========================================
# КОД ДЛЯ ОБУЧЕНИЯ
# ========================================
print("\n" + "=" * 70)
print("🚀 ГОТОВО! ЗАПУСКАЙ ОБУЧЕНИЕ")
print("=" * 70)
# Out:
# ======================================================================
# 📊 СОЗДАНИЕ TRAIN / VALID / TEST SPLITS
# ======================================================================
#
# 🔍 Текущая структура:
#
# 📸 Найдено изображений: 171
#
# 🔀 Разделение датасета...
#    📊 Train: 70%
#    📊 Valid: 20%
#    📊 Test:  10%
#
# ✅ Разделение выполнено:
#    Train: 119 изображений (69.6%)
#    Valid: 34 изображений (19.9%)
#    Test:  18 изображений (10.5%)
#
# 📁 Создание структуры папок...
#    ✅ train/images
#    ✅ train/labels
#    ✅ valid/images
#    ✅ valid/labels
#    ✅ test/images
#    ✅ test/labels
#
# 🚚 Перемещение файлов...
#    ✅ train: 119 файлов перемещено
#    ✅ valid: 34 файлов перемещено
#    ✅ test: 18 файлов перемещено
#
# 📝 Обновление data.yaml...
#    ✅ data.yaml обновлен
#
# ======================================================================
# ✅ ИТОГОВАЯ СТРУКТУРА
# ======================================================================
#
# 📄 Конфигурация data.yaml:
# names:
# - detail
# - legend
# - note
# - plan
# - section
# - site_plan
# - stamp
# - table
# nc: 8
# roboflow:
#   license: MIT
#   project: project_test_1-qlnqb
#   url: https://universe.roboflow.com/tets1-k0emt/project_test_1-qlnqb/dataset/3
#   version: 3
#   workspace: tets1-k0emt
# test: test/images
# train: train/images
# val: valid/images
#
#
# 📊 Статистика по splits:
# ✅ TRAIN  → Images:  119 | Labels:  119
# ✅ VALID  → Images:   34 | Labels:   34
# ✅ TEST   → Images:   18 | Labels:   18
#
# ======================================================================
# 🚀 ГОТОВО! ЗАПУСКАЙ ОБУЧЕНИЕ
# ======================================================================

# %%
import yaml
import os

# Путь к data.yaml
dataset_path = '/content/Project_Test_1-3/data.yaml'

# Читаем конфиг
with open(dataset_path, 'r') as f:
    config = yaml.safe_load(f)

# Исправляем пути на абсолютные
base_path = '/content/Project_Test_1-3'
config['train'] = f'{base_path}/train/images'
config['val'] = f'{base_path}/valid/images'
config['test'] = f'{base_path}/test/images'

# Сохраняем обновленный конфиг
with open(dataset_path, 'w') as f:
    yaml.dump(config, f, default_flow_style=False)

print("✅ data.yaml обновлен с абсолютными путями:")
print(f"   Train: {config['train']}")
print(f"   Valid: {config['val']}")
print(f"   Test: {config['test']}")
print()

# Проверка существования папок
for split in ['train', 'valid', 'test']:
    img_path = f'{base_path}/{split}/images'
    lbl_path = f'{base_path}/{split}/labels'

    img_count = len([f for f in os.listdir(img_path) if f.endswith(('.jpg', '.png'))])
    lbl_count = len([f for f in os.listdir(lbl_path) if f.endswith('.txt')])

    print(f"📊 {split.upper()}: {img_count} images, {lbl_count} labels")
# Out:
# ✅ data.yaml обновлен с абсолютными путями:
#    Train: /content/Project_Test_1-3/train/images
#    Valid: /content/Project_Test_1-3/valid/images
#    Test: /content/Project_Test_1-3/test/images
#
# 📊 TRAIN: 119 images, 119 labels
# 📊 VALID: 34 images, 34 labels
# 📊 TEST: 18 images, 18 labels

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# В параметрах model.train():
project='/content/drive/MyDrive/yolo8x_training',  # Сохранение на Drive
save_period=5,  # Сохранять каждые 5 эпох

# %%
from ultralytics import YOLO
import yaml
import os

# ====== 1. ПУТИ В data.yaml ======
dataset_path = '/content/Project_Test_1-3/data.yaml'
base_path = '/content/Project_Test_1-3'

# ====== 2. ПРОВЕРКА ДАТАСЕТА ======
print("📊 Проверка датасета:")
for split in ['train', 'valid', 'test']:
    img_path = f'{base_path}/{split}/images'
    lbl_path = f'{base_path}/{split}/labels'

    if os.path.exists(img_path):
        img_count = len([f for f in os.listdir(img_path) if f.endswith(('.jpg', '.png'))])
        lbl_count = len([f for f in os.listdir(lbl_path) if f.endswith('.txt')])
        print(f"   {split.upper()}: {img_count} images, {lbl_count} labels")
    else:
        print(f"   ❌ {split.upper()}: папка не найдена!")

print("\n" + "="*70)
print("🚀 МОЖНО ЗАПУСКАТЬ ОБУЧЕНИЕ")
print("="*70 + "\n")
# Out:
# 📊 Проверка датасета:
#    TRAIN: 119 images, 119 labels
#    VALID: 34 images, 34 labels
#    TEST: 18 images, 18 labels
#
# ======================================================================
# 🚀 МОЖНО ЗАПУСКАТЬ ОБУЧЕНИЕ
# ======================================================================

# %% [markdown]
# ДООБУЧЕНИЕ НОВОЙ МОДЕЛИ

# %%
from ultralytics import YOLO

# ====== ЗАГРУЗКА САМОЙ МОЩНОЙ МОДЕЛИ YOLOv8 ======
model = YOLO('yolov8x.pt')  # ← YOLOv8x - самая большая и точная!
print("✅ Загружена YOLOv8x (самая мощная модель)")

# ====== ОБУЧЕНИЕ ДЛЯ СТРОИТЕЛЬНЫХ ЧЕРТЕЖЕЙ ======
results = model.train(
    data='/content/Project_Test_1-3/data.yaml',

    # Основные параметры
    epochs=100,
    imgsz=1280,
    batch=4,
    device=0,

    # Валидация и сохранение
    val=True,
    patience=20,
    save=True,
    save_period=10,

    # Оптимизатор
    optimizer='AdamW',
    lr0=0.0005,
    lrf=0.001,
    weight_decay=0.0005,
    warmup_epochs=5,

    # Аугментации (минимальные для чертежей)
    hsv_h=0.005,
    hsv_s=0.3,
    hsv_v=0.2,
    degrees=0,
    translate=0.05,
    scale=0.3,
    shear=0,
    perspective=0.0,
    flipud=0.0,
    fliplr=0.0,
    mosaic=0.5,
    mixup=0.0,
    copy_paste=0.0,

    # Дополнительно
    close_mosaic=20,
    amp=True,
    plots=True,
    verbose=True,
    # Название проекта
    project='runs/detect',
    name='new_yolov8x'
)

print(f"🎉 Обучение завершено!")
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8x.pt to 'yolov8x.pt': 100% ━━━━━━━━━━━━ 130.5MB 202.1MB/s 0.6s
# ✅ Загружена YOLOv8x (самая мощная модель)
# Ultralytics 8.4.7 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=4, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=20, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/Project_Test_1-3/data.yaml, degrees=0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.0, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.005, hsv_s=0.3, hsv_v=0.2, imgsz=1280, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.0005, lrf=0.001, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8x.pt, momentum=0.937, mosaic=0.5, multi_scale=0.0, name=new_yolov8x, nbs=64, nms=False, opset=None, optimize=False, optimizer=AdamW, overlap_mask=True, patience=20, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=runs/detect, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/content/runs/detect/runs/detect/new_yolov8x, save_frames=False, save_json=False, save_period=10, save_txt=False, scale=0.3, seed=0, shear=0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.05, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=5, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 114.2MB/s 0.0s
# Overriding model.yaml nc=80 with nc=8
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      2320  ultralytics.nn.modules.conv.Conv             [3, 80, 3, 2]
#   1                  -1  1    115520  ultralytics.nn.modules.conv.Conv             [80, 160, 3, 2]
#   2                  -1  3    436800  ultralytics.nn.modules.block.C2f             [160, 160, 3, True]
#   3                  -1  1    461440  ultralytics.nn.modules.conv.Conv             [160, 320, 3, 2]
#   4                  -1  6   3281920  ultralytics.nn.modules.block.C2f             [320, 320, 6, True]
#   5                  -1  1   1844480  ultralytics.nn.modules.conv.Conv             [320, 640, 3, 2]
#   6                  -1  6  13117440  ultralytics.nn.modules.block.C2f             [640, 640, 6, True]
#   7                  -1  1   3687680  ultralytics.nn.modules.conv.Conv             [640, 640, 3, 2]
#   8                  -1  3   6969600  ultralytics.nn.modules.block.C2f             [640, 640, 3, True]
#   9                  -1  1   1025920  ultralytics.nn.modules.block.SPPF            [640, 640, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  3   7379200  ultralytics.nn.modules.block.C2f             [1280, 640, 3]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  3   1948800  ultralytics.nn.modules.block.C2f             [960, 320, 3]
#  16                  -1  1    922240  ultralytics.nn.modules.conv.Conv             [320, 320, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  3   7174400  ultralytics.nn.modules.block.C2f             [960, 640, 3]
#  19                  -1  1   3687680  ultralytics.nn.modules.conv.Conv             [640, 640, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  3   7379200  ultralytics.nn.modules.block.C2f             [1280, 640, 3]
#  22        [15, 18, 21]  1   8725672  ultralytics.nn.modules.head.Detect           [8, 16, None, [320, 640, 640]]
# Model summary: 210 layers, 68,160,312 parameters, 68,160,296 gradients, 258.2 GFLOPs
#
# Transferred 589/595 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 299.9MB/s 0.0s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2506.4±586.8 MB/s, size: 196.3 KB)
# train: Scanning /content/Project_Test_1-3/train/labels... 119 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 119/119 2.4Kit/s 0.0s
# train: New cache created: /content/Project_Test_1-3/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 895.9±648.8 MB/s, size: 190.7 KB)
# val: Scanning /content/Project_Test_1-3/valid/labels... 34 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 34/34 978.0it/s 0.0s
# val: New cache created: /content/Project_Test_1-3/valid/labels.cache
# Plotting labels to /content/runs/detect/runs/detect/new_yolov8x/labels.jpg...
# optimizer: AdamW(lr=0.0005, momentum=0.937) with parameter groups 97 weight(decay=0.0), 104 weight(decay=0.0005), 103 bias(decay=0.0)
# Image sizes 1280 train, 1280 val
# Using 2 dataloader workers
# Logging results to /content/runs/detect/runs/detect/new_yolov8x
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/100      12.2G     0.3685     0.2404     0.8618         13       1280: 100% ━━━━━━━━━━━━ 30/30 1.2s/it 35.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.2it/s 4.0s
#                    all         34        218      0.919      0.941       0.97      0.831
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/100      12.3G     0.3394     0.2264     0.8667         21       1280: 100% ━━━━━━━━━━━━ 30/30 1.2s/it 35.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.2it/s 4.0s
#                    all         34        218      0.917      0.943      0.971       0.83
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/100      12.3G     0.3457     0.2296     0.8665         16       1280: 100% ━━━━━━━━━━━━ 30/30 1.2s/it 35.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.2it/s 4.0s
#                    all         34        218      0.918      0.946      0.975      0.833
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/100      12.3G     0.3252     0.2211     0.8503         15       1280: 100% ━━━━━━━━━━━━ 30/30 1.2s/it 35.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.3it/s 4.0s
#                    all         34        218      0.908      0.944      0.975      0.835
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/100      12.3G      0.343     0.2243     0.8537         23       1280: 100% ━━━━━━━━━━━━ 30/30 1.2s/it 35.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.3it/s 4.0s
#                    all         34        218      0.916      0.938       0.97      0.827
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/100      12.3G     0.3289     0.2275     0.8596         17       1280: 100% ━━━━━━━━━━━━ 30/30 1.2s/it 35.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.2it/s 4.0s
#                    all         34        218      0.918      0.936      0.975      0.831
#
# 100 epochs completed in 1.560 hours.
# Optimizer stripped from /content/runs/detect/runs/detect/new_yolov8x/weights/last.pt, 136.9MB
# Optimizer stripped from /content/runs/detect/runs/detect/new_yolov8x/weights/best.pt, 136.9MB
#
# Validating /content/runs/detect/runs/detect/new_yolov8x/weights/best.pt...
# Ultralytics 8.4.7 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 113 layers, 68,131,272 parameters, 0 gradients, 257.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.1it/s 4.5s
#                    all         34        218      0.908      0.945      0.975      0.835
#                 detail         17         86      0.977      0.965      0.992      0.872
#                 legend          7          8          1      0.773      0.906      0.811
#                   note         24         31      0.936      0.946      0.987      0.793
#                   plan         17         24      0.913          1       0.97      0.771
#                section          4          5      0.683          1      0.995      0.684
#              site_plan          9          9      0.887      0.872      0.973      0.887
#                  stamp         33         33       0.95          1      0.983      0.969
#                  table         12         22      0.917          1      0.993       0.89
# Speed: 1.2ms preprocess, 109.2ms inference, 0.0ms loss, 10.8ms postprocess per image
# Results saved to /content/runs/detect/runs/detect/new_yolov8x
# 🎉 Обучение завершено!

# %%
from ultralytics import YOLO

model = YOLO('yolov8x.pt')

results = model.train(
    data='/content/Project_Test_1-3/data.yaml',

    # ===== ОСНОВНЫЕ =====
    epochs=100,
    imgsz=1280,              # для мелких узлов и текста
    batch=4,
    device=0,

    # ===== ВАЛИДАЦИЯ =====
    val=True,
    patience=20,
    save=True,
    save_period=10,

    # ===== ОПТИМИЗАТОР =====
    optimizer='AdamW',
    lr0=0.001,               # ВЫШЕ (чистые данные учатся быстрее)
    lrf=0.00005,
    momentum=0.937,
    weight_decay=0.0005,
    warmup_epochs=3,         # меньше прогрева
    warmup_momentum=0.8,
    warmup_bias_lr=0.1,

    # ===== ЦВЕТОВЫЕ (AutoCAD = чистые данные) =====
    hsv_h=0.0,               # НЕТ! PDF всегда одинаковые
    hsv_s=0.0,               # НЕТ! Нет цветовых вариаций
    hsv_v=0.2,               # МИНИМУМ (только легкая яркость)

    # ===== ГЕОМЕТРИЧЕСКИЕ =====
    degrees=3,               # PDF почти всегда ровные
    translate=0.05,          # минимальный сдвиг
    scale=0.3,               # разные масштабы узлов/планов
    shear=0,                 # НЕТ! Векторные линии не искажаются
    perspective=0.0001,      # минимум

    # ===== ОТРАЖЕНИЯ =====
    flipud=0.0,              # НЕТ
    fliplr=0.35,             # редко

    # ===== ПРОДВИНУТЫЕ =====
    mosaic=0.3,              # ЕЩЁ НИЖЕ (чистые данные = меньше аугментаций)
    mixup=0.0,               # НЕТ
    copy_paste=0.05,         # минимум
    erasing=0.15,            # меньше (нет артефактов сканов)
    auto_augment=None,       # ОТКЛЮЧИЛ (AutoCAD = идеальные данные)
    crop_fraction=1.0,
    close_mosaic=30,         # раньше закрыть мозаику

    # ===== LOSS =====
    box=8.5,                 # ВЫШЕ (векторные линии = точные границы)
    cls=0.4,
    dfl=2.0,                 # ВЫШЕ для мелких узлов

    # ===== ДОПОЛНИТЕЛЬНО =====
    dropout=0.0,
    label_smoothing=0.0,

    # ===== ПРОИЗВОДИТЕЛЬНОСТЬ =====
    amp=True,
    cache=False,
    workers=8,
    rect=False,

    # ===== ВИЗУАЛИЗАЦИЯ =====
    plots=True,
    verbose=True,
    save_txt=True,
    save_conf=True,

    project='runs/detect',
    name='blueprint_autocad_clean'
)

print(f"\n{'='*80}")
print(f"✅ Модель для чистых AutoCAD PDF готова!")
print(f"📊 Веса: {results.save_dir}/weights/best.pt")
print(f"{'='*80}")
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8x.pt to 'yolov8x.pt': 100% ━━━━━━━━━━━━ 130.5MB 102.0MB/s 1.3s
# WARNING ⚠️ 'label_smoothing' is deprecated and will be removed in the future.
# WARNING ⚠️ 'crop_fraction' is deprecated and will be removed in the future.
# Ultralytics 8.4.7 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=None, batch=4, bgr=0.0, box=8.5, cache=False, cfg=None, classes=None, close_mosaic=30, cls=0.4, compile=False, conf=None, copy_paste=0.05, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/Project_Test_1-3/data.yaml, degrees=3, deterministic=True, device=0, dfl=2.0, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.15, exist_ok=False, fliplr=0.35, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.0, hsv_s=0.0, hsv_v=0.2, imgsz=1280, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.001, lrf=5e-05, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8x.pt, momentum=0.937, mosaic=0.3, multi_scale=0.0, name=blueprint_autocad_clean, nbs=64, nms=False, opset=None, optimize=False, optimizer=AdamW, overlap_mask=True, patience=20, perspective=0.0001, plots=True, pose=12.0, pretrained=True, profile=False, project=runs/detect, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=True, save_crop=False, save_dir=/content/runs/detect/runs/detect/blueprint_autocad_clean, save_frames=False, save_json=False, save_period=10, save_txt=True, scale=0.3, seed=0, shear=0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.05, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 22.2MB/s 0.0s
# Overriding model.yaml nc=80 with nc=8
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      2320  ultralytics.nn.modules.conv.Conv             [3, 80, 3, 2]
#   1                  -1  1    115520  ultralytics.nn.modules.conv.Conv             [80, 160, 3, 2]
#   2                  -1  3    436800  ultralytics.nn.modules.block.C2f             [160, 160, 3, True]
#   3                  -1  1    461440  ultralytics.nn.modules.conv.Conv             [160, 320, 3, 2]
#   4                  -1  6   3281920  ultralytics.nn.modules.block.C2f             [320, 320, 6, True]
#   5                  -1  1   1844480  ultralytics.nn.modules.conv.Conv             [320, 640, 3, 2]
#   6                  -1  6  13117440  ultralytics.nn.modules.block.C2f             [640, 640, 6, True]
#   7                  -1  1   3687680  ultralytics.nn.modules.conv.Conv             [640, 640, 3, 2]
#   8                  -1  3   6969600  ultralytics.nn.modules.block.C2f             [640, 640, 3, True]
#   9                  -1  1   1025920  ultralytics.nn.modules.block.SPPF            [640, 640, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  3   7379200  ultralytics.nn.modules.block.C2f             [1280, 640, 3]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  3   1948800  ultralytics.nn.modules.block.C2f             [960, 320, 3]
#  16                  -1  1    922240  ultralytics.nn.modules.conv.Conv             [320, 320, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  3   7174400  ultralytics.nn.modules.block.C2f             [960, 640, 3]
#  19                  -1  1   3687680  ultralytics.nn.modules.conv.Conv             [640, 640, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  3   7379200  ultralytics.nn.modules.block.C2f             [1280, 640, 3]
#  22        [15, 18, 21]  1   8725672  ultralytics.nn.modules.head.Detect           [8, 16, None, [320, 640, 640]]
# Model summary: 210 layers, 68,160,312 parameters, 68,160,296 gradients, 258.2 GFLOPs
#
# Transferred 589/595 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 94.6MB/s 0.1s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.1±0.2 ms, read: 2031.3±743.4 MB/s, size: 196.3 KB)
# train: Scanning /content/Project_Test_1-3/train/labels... 119 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 119/119 2.5Kit/s 0.0s
# train: New cache created: /content/Project_Test_1-3/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 838.2±753.2 MB/s, size: 190.7 KB)
# val: Scanning /content/Project_Test_1-3/valid/labels... 34 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 34/34 1.1Kit/s 0.0s
# val: New cache created: /content/Project_Test_1-3/valid/labels.cache
# Plotting labels to /content/runs/detect/runs/detect/blueprint_autocad_clean/labels.jpg...
# optimizer: AdamW(lr=0.001, momentum=0.937) with parameter groups 97 weight(decay=0.0), 104 weight(decay=0.0005), 103 bias(decay=0.0)
# Image sizes 1280 train, 1280 val
# Using 2 dataloader workers
# Logging results to /content/runs/detect/runs/detect/blueprint_autocad_clean
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      11.5G      1.804      3.061       2.55         34       1280: 100% ━━━━━━━━━━━━ 30/30 1.2s/it 35.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.8s/it 14.2s
#                    all         34        218      0.951      0.112      0.153     0.0904
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      12.3G      1.541      2.229      2.324         23       1280: 100% ━━━━━━━━━━━━ 30/30 1.2s/it 35.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.6s/it 13.2s
#                    all         34        218      0.302        0.2     0.0466     0.0198
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100        12G      1.404      2.473      2.177         28       1280: 100% ━━━━━━━━━━━━ 30/30 1.2s/it 37.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.6s/it 13.2s
#                    all         34        218    0.00732     0.0559    0.00522    0.00141
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      12.2G       1.88      2.428      2.559         21       1280: 100% ━━━━━━━━━━━━ 30/30 1.2s/it 36.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.6s/it 13.1s
#                    all         34        218    0.00119     0.0733   0.000876   0.000312
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      12.3G       1.72      2.127      2.408         12       1280: 100% ━━━━━━━━━━━━ 30/30 1.2s/it 36.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.6s/it 12.9s
#                    all         34        218      0.333      0.325      0.129     0.0629
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100        12G       1.73      2.069      2.421         52       1280: 100% ━━━━━━━━━━━━ 30/30 1.2s/it 36.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.6s/it 12.8s
#                    all         34        218       0.37      0.176      0.178     0.0755
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      12.2G      1.443      1.915      2.139         15       1280: 100% ━━━━━━━━━━━━ 30/30 1.2s/it 36.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.6s/it 13.1s
#                    all         34        218      0.341      0.293      0.156     0.0907

# %% [markdown]
# ДООБУЧЕНИЕ МОДЕЛИ

# %%
from ultralytics import YOLO

# =============================================================================
# ЭТАП 1: ОБУЧЕНИЕ НА ЧЕРНО-БЕЛЫХ ЧЕРТЕЖАХ
# =============================================================================

print("="*80)
print("ЭТАП 1: Дообучение на ЧБ строительных чертежах")
print("="*80)

model_stage1 = YOLO('/content/runs/detect/runs/detect/blueprint_yolov8x/weights/best.pt')

results_stage1 = model_stage1.train(
    data='/content/Project_Test_1-3/data.yaml',

    # Основные параметры
    epochs=100,
    imgsz=1280,              # Высокое разрешение для деталей
    batch=4,
    device=0,

    # Валидация
    val=True,
    patience=25,
    save=True,
    save_period=8,

    # Оптимизатор (файнтюнинг)
    optimizer='AdamW',
    lr0=0.0004,              # Низкий LR
    lrf=0.00002,
    momentum=0.95,
    weight_decay=0.0012,
    warmup_epochs=6,
    warmup_momentum=0.85,
    warmup_bias_lr=0.04,

    # Loss gains
    box=7.8,
    cls=0.6,
    dfl=1.6,

    # ЦВЕТОВЫЕ АУГМЕНТАЦИИ (МИНИМУМ ДЛЯ ЧБ)
    hsv_h=0.003,             # Почти нет
    hsv_s=0.05,              # Минимум
    hsv_v=0.15,              # Только яркость

    # ГЕОМЕТРИЧЕСКИЕ АУГМЕНТАЦИИ
    degrees=3,
    translate=0.08,
    scale=0.25,
    shear=1.5,
    perspective=0.0001,

    # ОТРАЖЕНИЯ
    flipud=0.0,              # НЕТ! Чертежи не переворачиваются
    fliplr=0.5,              # Зеркальное отражение OK

    # ПРОДВИНУТЫЕ АУГМЕНТАЦИИ
    mosaic=0.7,
    mixup=0.0,
    copy_paste=0.05,
    erasing=0.08,
    crop_fraction=1.0,
    close_mosaic=25,

    # ДОПОЛНИТЕЛЬНО
    dropout=0.12,
    label_smoothing=0.0,

    # Производительность
    amp=True,
    cache='disk',
    workers=4,
    rect=False,              # Для разных форматов листов

    # Визуализация
    plots=True,
    verbose=True,
    save_txt=True,
    save_conf=True,

    project='runs/detect',
    name='stage1_bw_blueprints'
)

print(f"\n{'='*80}")
print(f"✅ ЭТАП 1 ЗАВЕРШЁН!")
print(f"📊 Модель сохранена: {results_stage1.save_dir}/weights/best.pt")
print(f"{'='*80}\n")
# Out:
# ================================================================================
# ЭТАП 1: Дообучение на ЧБ строительных чертежах
# ================================================================================
# WARNING ⚠️ 'crop_fraction' is deprecated and will be removed in the future.
# WARNING ⚠️ 'label_smoothing' is deprecated and will be removed in the future.
# Ultralytics 8.4.7 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=4, bgr=0.0, box=7.8, cache=disk, cfg=None, classes=None, close_mosaic=25, cls=0.6, compile=False, conf=None, copy_paste=0.05, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/Project_Test_1-3/data.yaml, degrees=3, deterministic=True, device=0, dfl=1.6, dnn=False, dropout=0.12, dynamic=False, embed=None, epochs=100, erasing=0.08, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.003, hsv_s=0.05, hsv_v=0.15, imgsz=1280, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.0004, lrf=2e-05, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=/content/runs/detect/runs/detect/blueprint_yolov8x/weights/best.pt, momentum=0.95, mosaic=0.7, multi_scale=0.0, name=stage1_bw_blueprints, nbs=64, nms=False, opset=None, optimize=False, optimizer=AdamW, overlap_mask=True, patience=25, perspective=0.0001, plots=True, pose=12.0, pretrained=True, profile=False, project=runs/detect, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=True, save_crop=False, save_dir=/content/runs/detect/runs/detect/stage1_bw_blueprints, save_frames=False, save_json=False, save_period=8, save_txt=True, scale=0.25, seed=0, shear=1.5, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.08, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.04, warmup_epochs=6, warmup_momentum=0.85, weight_decay=0.0012, workers=4, workspace=None
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      2320  ultralytics.nn.modules.conv.Conv             [3, 80, 3, 2]
#   1                  -1  1    115520  ultralytics.nn.modules.conv.Conv             [80, 160, 3, 2]
#   2                  -1  3    436800  ultralytics.nn.modules.block.C2f             [160, 160, 3, True]
#   3                  -1  1    461440  ultralytics.nn.modules.conv.Conv             [160, 320, 3, 2]
#   4                  -1  6   3281920  ultralytics.nn.modules.block.C2f             [320, 320, 6, True]
#   5                  -1  1   1844480  ultralytics.nn.modules.conv.Conv             [320, 640, 3, 2]
#   6                  -1  6  13117440  ultralytics.nn.modules.block.C2f             [640, 640, 6, True]
#   7                  -1  1   3687680  ultralytics.nn.modules.conv.Conv             [640, 640, 3, 2]
#   8                  -1  3   6969600  ultralytics.nn.modules.block.C2f             [640, 640, 3, True]
#   9                  -1  1   1025920  ultralytics.nn.modules.block.SPPF            [640, 640, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  3   7379200  ultralytics.nn.modules.block.C2f             [1280, 640, 3]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  3   1948800  ultralytics.nn.modules.block.C2f             [960, 320, 3]
#  16                  -1  1    922240  ultralytics.nn.modules.conv.Conv             [320, 320, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  3   7174400  ultralytics.nn.modules.block.C2f             [960, 640, 3]
#  19                  -1  1   3687680  ultralytics.nn.modules.conv.Conv             [640, 640, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  3   7379200  ultralytics.nn.modules.block.C2f             [1280, 640, 3]
#  22        [15, 18, 21]  1   8725672  ultralytics.nn.modules.head.Detect           [8, 16, None, [320, 640, 640]]
# Model summary: 210 layers, 68,160,312 parameters, 68,160,296 gradients, 258.2 GFLOPs
#
# Transferred 595/595 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2513.3±629.4 MB/s, size: 181.1 KB)
# train: Scanning /content/Project_Test_1-3/train/labels.cache... 119 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 119/119 35.7Mit/s 0.0s
# train: Caching images (0.5GB Disk): 100% ━━━━━━━━━━━━ 119/119 6.5it/s 18.3s
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 426.1±205.5 MB/s, size: 188.2 KB)
# val: Scanning /content/Project_Test_1-3/valid/labels.cache... 34 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 34/34 3.0Mit/s 0.0s
# val: Caching images (0.2GB Disk): 100% ━━━━━━━━━━━━ 34/34 10.6it/s 3.2s
# Plotting labels to /content/runs/detect/runs/detect/stage1_bw_blueprints/labels.jpg...
# optimizer: AdamW(lr=0.0004, momentum=0.95) with parameter groups 97 weight(decay=0.0), 104 weight(decay=0.0012), 103 bias(decay=0.0)
# Image sizes 1280 train, 1280 val
# Using 2 dataloader workers
# Logging results to /content/runs/detect/runs/detect/stage1_bw_blueprints
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      13.3G     0.6335     0.5698      1.181         29       1280: 100% ━━━━━━━━━━━━ 30/30 1.3s/it 38.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.0s/it 5.1s
#                    all         34        218      0.827      0.926      0.928      0.742
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100        12G     0.6699     0.5472      1.185         38       1280: 100% ━━━━━━━━━━━━ 30/30 1.2s/it 36.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.0it/s 5.0s
#                    all         34        218      0.809      0.905      0.931      0.772
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      12.3G     0.6393     0.5794      1.165         36       1280: 100% ━━━━━━━━━━━━ 30/30 1.2s/it 36.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.0it/s 4.8s
#                    all         34        218       0.89       0.81      0.924      0.749
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      12.3G     0.6682     0.5901      1.179         23       1280: 100% ━━━━━━━━━━━━ 30/30 1.2s/it 36.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.0s/it 5.0s
#                    all         34        218      0.742      0.942      0.923       0.72
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      12.3G     0.6626     0.6226      1.191         18       1280: 100% ━━━━━━━━━━━━ 30/30 1.2s/it 36.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.0s/it 5.0s
#                    all         34        218       0.82      0.902      0.915      0.726
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      12.3G     0.6826     0.6015      1.199         34       1280: 100% ━━━━━━━━━━━━ 30/30 1.2s/it 36.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.0it/s 4.9s
#                    all         34        218      0.874      0.903      0.923      0.739
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      12.2G     0.6578     0.5951      1.178         25       1280: 100% ━━━━━━━━━━━━ 30/30 1.2s/it 36.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.0it/s 4.9s
#                    all         34        218      0.895      0.805      0.899      0.709
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      12.3G     0.6743        0.6      1.185         19       1280: 100% ━━━━━━━━━━━━ 30/30 1.2s/it 36.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.0it/s 5.0s
#                    all         34        218      0.902       0.84      0.901       0.73
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      12.3G     0.6669     0.6141      1.198         24       1280: 100% ━━━━━━━━━━━━ 30/30 1.2s/it 36.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.0s/it 5.2s
#                    all         34        218      0.852      0.854      0.901      0.739
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      12.3G      0.668     0.6256      1.197         13       1280: 100% ━━━━━━━━━━━━ 30/30 1.2s/it 36.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.0s/it 5.2s
#                    all         34        218      0.809      0.925      0.892      0.711
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      12.3G      0.655     0.5927      1.188         51       1280: 100% ━━━━━━━━━━━━ 30/30 1.2s/it 36.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.1s/it 5.3s
#                    all         34        218      0.846      0.924      0.925      0.737
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100      12.3G     0.6666     0.6224      1.188         52       1280: 100% ━━━━━━━━━━━━ 30/30 1.2s/it 36.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.1s/it 5.3s
#                    all         34        218      0.873      0.935      0.952      0.758
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100      12.3G     0.6457     0.5828      1.185         20       1280: 100% ━━━━━━━━━━━━ 30/30 1.2s/it 36.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.0s/it 5.2s
#                    all         34        218      0.891      0.917      0.947      0.753
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100      12.3G     0.6054     0.5287      1.123         15       1280: 100% ━━━━━━━━━━━━ 30/30 1.2s/it 36.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.0it/s 5.0s
#                    all         34        218      0.891      0.895      0.934      0.748
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100      12.3G      0.622     0.5742      1.163         25       1280: 100% ━━━━━━━━━━━━ 30/30 1.2s/it 36.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.0s/it 5.1s
#                    all         34        218      0.893      0.876      0.931      0.756
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100      12.3G     0.6159     0.5233      1.153         27       1280: 100% ━━━━━━━━━━━━ 30/30 1.2s/it 36.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.0s/it 5.1s
#                    all         34        218       0.85       0.88      0.911      0.739
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/100      12.3G     0.6141     0.5365      1.155         33       1280: 100% ━━━━━━━━━━━━ 30/30 1.2s/it 36.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.0it/s 5.0s
#                    all         34        218      0.858      0.903      0.926      0.758
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/100      12.3G     0.6358     0.5355      1.154         33       1280: 100% ━━━━━━━━━━━━ 30/30 1.2s/it 36.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.0it/s 4.9s
#                    all         34        218      0.846      0.908       0.94      0.763
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/100      12.3G     0.6218     0.5366      1.165         23       1280: 100% ━━━━━━━━━━━━ 30/30 1.2s/it 36.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.0it/s 5.0s
#                    all         34        218      0.849       0.91       0.93       0.74
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3547101909.py in <cell line: 0>()
#      11 model_stage1 = YOLO('/content/runs/detect/runs/detect/blueprint_yolov8x/weights/best.pt')
#      12
# ---> 13 results_stage1 = model_stage1.train(
#      14     data='/content/Project_Test_1-3/data.yaml',
#      15
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/model.py in train(self, trainer, **kwargs)
#     772             self.model = self.trainer.model
#     773
# --> 774         self.trainer.train()
#     775         # Update model and cfg after training
#     776         if RANK in {-1, 0}:
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/trainer.py in train(self)
#     242
#     243         else:
# --> 244             self._do_train()
#     245
#     246     def _setup_scheduler(self):
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/trainer.py in _do_train(self)
#     500                 # Save model
#     501                 if self.args.save or final_epoch:
# --> 502                     self.save_model()
#     503                     self.run_callbacks("on_model_save")
#     504
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/trainer.py in save_model(self)
#     626         # Save checkpoints
#     627         self.wdir.mkdir(parents=True, exist_ok=True)  # ensure weights directory exists
# --> 628         self.last.write_bytes(serialized_ckpt)  # save last.pt
#     629         if self.best_fitness == self.fitness:
#     630             self.best.write_bytes(serialized_ckpt)  # save best.pt
#
# /usr/lib/python3.12/pathlib.py in write_bytes(self, data)
#    1035         view = memoryview(data)
#    1036         with self.open(mode='wb') as f:
# -> 1037             return f.write(view)
#    1038
#    1039     def write_text(self, data, encoding=None, errors=None, newline=None):
#
# KeyboardInterrupt:

# %%
from ultralytics import YOLO

# ====== ЗАГРУЗКА ОБУЧЕННОЙ МОДЕЛИ ======
model = YOLO('/content/runs/detect/train/weights/best.pt')  # ← ваша модель

print("✅ Загружена обученная модель для дообучения")

# ====== ДООБУЧЕНИЕ С МЕНЬШИМ LR ======
results = model.train(
    data='/content/Project_Test_1-3/data.yaml',

    # Параметры для fine-tuning
    epochs=30,              # ← меньше эпох
    imgsz=1024,
    batch=6,
    device=0,

    # Валидация
    val=True,
    patience=15,            # ← больше терпения
    save=True,
    save_period=5,

    # ВАЖНО: уменьшенный learning rate для fine-tuning
    optimizer='AdamW',
    lr0=0.0001,            # ← в 5 раз меньше!
    lrf=0.0001,
    weight_decay=0.0005,
    warmup_epochs=3,

    # Аугментации (можно еще уменьшить)
    hsv_h=0.005,
    hsv_s=0.2,
    hsv_v=0.2,
    degrees=0,
    translate=0.03,
    scale=0.2,
    shear=0,
    perspective=0.0,
    flipud=0.0,
    fliplr=0.0,
    mosaic=0.3,
    mixup=0.0,
    copy_paste=0.0,

    close_mosaic=10,
    amp=True,
    plots=True,
    verbose=True,

    # Название проекта
    project='runs/detect',
    name='finetune'         # ← чтобы отличить от первого обучения
)

print(f"🎉 Дообучение завершено!")
print(f"📁 Результаты: {results.save_dir}")
# Out:
# ✅ Загружена обученная модель для дообучения
# Ultralytics 8.4.7 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=6, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/Project_Test_1-3/data.yaml, degrees=0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=30, erasing=0.4, exist_ok=False, fliplr=0.0, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.005, hsv_s=0.2, hsv_v=0.2, imgsz=1024, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.0001, lrf=0.0001, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=/content/runs/detect/train/weights/best.pt, momentum=0.937, mosaic=0.3, multi_scale=0.0, name=finetune, nbs=64, nms=False, opset=None, optimize=False, optimizer=AdamW, overlap_mask=True, patience=15, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=runs/detect, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/content/runs/detect/runs/detect/finetune, save_frames=False, save_json=False, save_period=5, save_txt=False, scale=0.2, seed=0, shear=0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.03, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 23.8MB/s 0.0s
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      2320  ultralytics.nn.modules.conv.Conv             [3, 80, 3, 2]
#   1                  -1  1    115520  ultralytics.nn.modules.conv.Conv             [80, 160, 3, 2]
#   2                  -1  3    436800  ultralytics.nn.modules.block.C2f             [160, 160, 3, True]
#   3                  -1  1    461440  ultralytics.nn.modules.conv.Conv             [160, 320, 3, 2]
#   4                  -1  6   3281920  ultralytics.nn.modules.block.C2f             [320, 320, 6, True]
#   5                  -1  1   1844480  ultralytics.nn.modules.conv.Conv             [320, 640, 3, 2]
#   6                  -1  6  13117440  ultralytics.nn.modules.block.C2f             [640, 640, 6, True]
#   7                  -1  1   3687680  ultralytics.nn.modules.conv.Conv             [640, 640, 3, 2]
#   8                  -1  3   6969600  ultralytics.nn.modules.block.C2f             [640, 640, 3, True]
#   9                  -1  1   1025920  ultralytics.nn.modules.block.SPPF            [640, 640, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  3   7379200  ultralytics.nn.modules.block.C2f             [1280, 640, 3]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  3   1948800  ultralytics.nn.modules.block.C2f             [960, 320, 3]
#  16                  -1  1    922240  ultralytics.nn.modules.conv.Conv             [320, 320, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  3   7174400  ultralytics.nn.modules.block.C2f             [960, 640, 3]
#  19                  -1  1   3687680  ultralytics.nn.modules.conv.Conv             [640, 640, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  3   7379200  ultralytics.nn.modules.block.C2f             [1280, 640, 3]
#  22        [15, 18, 21]  1   8725672  ultralytics.nn.modules.head.Detect           [8, 16, None, [320, 640, 640]]
# Model summary: 210 layers, 68,160,312 parameters, 68,160,296 gradients, 258.2 GFLOPs
#
# Transferred 595/595 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 99.9MB/s 0.1s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2712.7±782.0 MB/s, size: 196.3 KB)
# train: Scanning /content/Project_Test_1-3/train/labels... 119 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 119/119 2.4Kit/s 0.1s
# train: New cache created: /content/Project_Test_1-3/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1049.7±851.9 MB/s, size: 190.7 KB)
# val: Scanning /content/Project_Test_1-3/valid/labels... 34 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 34/34 1.3Kit/s 0.0s
# val: New cache created: /content/Project_Test_1-3/valid/labels.cache
# Plotting labels to /content/runs/detect/runs/detect/finetune/labels.jpg...
# optimizer: AdamW(lr=0.0001, momentum=0.937) with parameter groups 97 weight(decay=0.0), 104 weight(decay=0.000515625), 103 bias(decay=0.0)
# Image sizes 1024 train, 1024 val
# Using 2 dataloader workers
# Logging results to /content/runs/detect/runs/detect/finetune
# Starting training for 30 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/30      11.3G     0.6028     0.6282      1.043         51       1024: 100% ━━━━━━━━━━━━ 20/20 1.1s/it 22.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.1s/it 3.3s
#                    all         34        218      0.727      0.776      0.773      0.653
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/30      11.8G      0.567       0.49      1.023         48       1024: 100% ━━━━━━━━━━━━ 20/20 1.1s/it 21.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.1it/s 2.6s
#                    all         34        218      0.745      0.823      0.817      0.703
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/30      11.7G     0.5424     0.4732     0.9955         38       1024: 100% ━━━━━━━━━━━━ 20/20 1.1s/it 22.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.2it/s 2.6s
#                    all         34        218      0.881      0.847      0.896      0.772
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/30      11.5G     0.5274     0.4282     0.9747         45       1024: 100% ━━━━━━━━━━━━ 20/20 1.1s/it 22.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.1it/s 2.7s
#                    all         34        218      0.929      0.835      0.905      0.784
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/30      11.7G     0.5101     0.4275     0.9833         30       1024: 100% ━━━━━━━━━━━━ 20/20 1.2s/it 23.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.1it/s 2.8s
#                    all         34        218      0.897      0.853      0.903      0.787
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/30      11.7G     0.5132      0.451     0.9832         61       1024: 100% ━━━━━━━━━━━━ 20/20 1.2s/it 23.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.1it/s 2.8s
#                    all         34        218      0.884      0.867      0.906      0.797
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/30      11.8G     0.4809     0.4026     0.9656         29       1024: 100% ━━━━━━━━━━━━ 20/20 1.2s/it 23.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.1it/s 2.8s
#                    all         34        218      0.927      0.866      0.932      0.811
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/30      11.7G     0.4908     0.3908     0.9599         48       1024: 100% ━━━━━━━━━━━━ 20/20 1.2s/it 23.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.1it/s 2.8s
#                    all         34        218      0.939      0.904      0.944      0.824
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/30      11.6G     0.4923      0.401      0.953         35       1024: 100% ━━━━━━━━━━━━ 20/20 1.2s/it 23.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.1it/s 2.8s
#                    all         34        218        0.9      0.915      0.944      0.822
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10
8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.0it/s 2.9s
#                    all         34        218       0.95      0.887      0.953      0.845
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/30      11.7G     0.3686     0.2547     0.8831         53       1024: 100% ━━━━━━━━━━━━ 20/20 1.2s/it 23.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.1it/s 2.7s
#                    all         34        218      0.953      0.884      0.955      0.848
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/30      11.7G     0.3628     0.2448     0.8947         32       1024: 100% ━━━━━━━━━━━━ 20/20 1.2s/it 23.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.1it/s 2.8s
#                    all         34        218      0.951      0.879      0.954      0.847
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/30      11.7G     0.3606     0.2471     0.8823         28       1024: 100% ━━━━━━━━━━━━ 20/20 1.2s/it 23.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.1it/s 2.8s
#                    all         34        218      0.958      0.881      0.958      0.848
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/30      11.7G     0.3753     0.2515     0.8906         48       1024: 100% ━━━━━━━━━━━━ 20/20 1.2s/it 23.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.1it/s 2.8s
#                    all         34        218      0.958      0.882      0.958      0.847
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/30      11.8G     0.3601     0.2513     0.8827         37       1024: 100% ━━━━━━━━━━━━ 20/20 1.2s/it 24.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.1it/s 2.8s
#                    all         34        218      0.956      0.883      0.958      0.849
#
# 30 epochs completed in 0.356 hours.
# Optimizer stripped from /content/runs/detect/runs/detect/finetune/weights/last.pt, 136.8MB
# Optimizer stripped from /content/runs/detect/runs/detect/finetune/weights/best.pt, 136.8MB
#
# Validating /content/runs/detect/runs/detect/finetune/weights/best.pt...
# Ultralytics 8.4.7 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 113 layers, 68,131,272 parameters, 0 gradients, 257.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 1.0it/s 3.0s
#                    all         34        218      0.958      0.878      0.958      0.847
#                 detail         17         86      0.984      0.988      0.994       0.89
#                 legend          7          8          1      0.523      0.775      0.714
#                   note         24         31      0.867      0.845      0.939       0.75
#                   plan         17         24      0.991      0.875      0.987      0.895
#                section          4          5      0.874          1      0.995      0.842
#              site_plan          9          9          1      0.791      0.984      0.819
#                  stamp         33         33      0.994          1      0.995      0.963
#                  table         12         22      0.953          1      0.993      0.899
# Speed: 0.6ms preprocess, 75.0ms inference, 0.0ms loss, 3.5ms postprocess per image
# Results saved to /content/runs/detect/runs/detect/finetune
# 🎉 Дообучение завершено!
# 📁 Результаты: /content/runs/detect/runs/detect/finetune

# %%
from ultralytics import YOLO
from google.colab import files

# Экспорт в ONNX
model = YOLO('/content/runs/detect/runs/detect/new_yolov8x/weights/best.pt')
onnx_path = model.export(format='onnx', imgsz=1280, simplify=True)

# Скачивание
files.download('/content/runs/detect/runs/detect/new_yolov8x/weights/best.pt')
files.download('/content/runs/detect/runs/detect/new_yolov8x/weights/best.onnx')

print("✅ Модели скачаны!")
# Out:
# Ultralytics 8.4.7 🚀 Python-3.12.12 torch-2.9.0+cu126 CPU (Intel Xeon CPU @ 2.00GHz)
# 💡 ProTip: Export to OpenVINO format for best performance on Intel hardware. Learn more at https://docs.ultralytics.com/integrations/openvino/
# Model summary (fused): 113 layers, 68,131,272 parameters, 0 gradients, 257.4 GFLOPs
#
# PyTorch: starting from '/content/runs/detect/runs/detect/new_yolov8x/weights/best.pt' with input shape (1, 3, 1280, 1280) BCHW and output shape(s) (1, 12, 33600) (130.6 MB)
# requirements: Ultralytics requirements ['onnx>=1.12.0,<2.0.0', 'onnxslim>=0.1.71', 'onnxruntime-gpu'] not found, attempting AutoUpdate...
# Using Python 3.12.12 environment at: /usr
# Resolved 14 packages in 114ms
# Prepared 6 packages in 9.79s
# Installed 6 packages in 446ms
#  + colorama==0.4.6
#  + coloredlogs==15.0.1
#  + humanfriendly==10.0
#  + onnx==1.20.1
#  + onnxruntime-gpu==1.23.2
#  + onnxslim==0.1.82
#
# requirements: AutoUpdate success ✅ 11.1s
# WARNING ⚠️ requirements: Restart runtime or rerun command for updates to take effect
#
#
# ONNX: starting export with onnx 1.20.1 opset 22...
# Exporting to ONNX opset version 22 is not supported. by 'torch.onnx.export()'. The highest opset version supported is 20. To use a newer opset version, consider 'torch.onnx.export(..., dynamo=True)'.
# ONNX: slimming with onnxslim 0.1.82...
# ONNX: export success ✅ 35.6s, saved as '/content/runs/detect/runs/detect/new_yolov8x/weights/best.onnx' (260.7 MB)
#
# Export complete (59.7s)
# Results saved to /content/runs/detect/runs/detect/new_yolov8x/weights
# Predict:         yolo predict task=detect model=/content/runs/detect/runs/detect/new_yolov8x/weights/best.onnx imgsz=1280
# Validate:        yolo val task=detect model=/content/runs/detect/runs/detect/new_yolov8x/weights/best.onnx imgsz=1280 data=/content/Project_Test_1-3/data.yaml
# Visualize:       https://netron.app
# ✅ Модели скачаны!

# %%
from IPython.display import Image, display
import pandas as pd
import os

print("="*70)
print("📊 ПОЛНАЯ ВИЗУАЛИЗАЦИЯ РЕЗУЛЬТАТОВ ОБУЧЕНИЯ")
print("="*70)

# ПРАВИЛЬНЫЙ путь (двойной, как на скриншоте)
results_path = '/content/runs/detect/runs/detect/new_yolov8x'

# 1. ГРАФИКИ МЕТРИК ОБУЧЕНИЯ
print("\n📈 ГРАФИКИ МЕТРИК ОБУЧЕНИЯ (loss, mAP, precision, recall)")
print("-"*70)
display(Image(filename=os.path.join(results_path, 'results.png')))

# 2. CONFUSION MATRICES
print("\n🎯 CONFUSION MATRIX")
print("-"*70)
display(Image(filename=os.path.join(results_path, 'confusion_matrix.png')))

print("\n🎯 NORMALIZED CONFUSION MATRIX")
print("-"*70)
display(Image(filename=os.path.join(results_path, 'confusion_matrix_normalized.png')))

# 3. F1, PRECISION, RECALL КРИВЫЕ
print("\n📊 F1-CONFIDENCE CURVE")
print("-"*70)
display(Image(filename=os.path.join(results_path, 'BoxF1_curve.png')))

print("\n📊 PRECISION-CONFIDENCE CURVE")
print("-"*70)
display(Image(filename=os.path.join(results_path, 'BoxP_curve.png')))

print("\n📊 RECALL-CONFIDENCE CURVE")
print("-"*70)
display(Image(filename=os.path.join(results_path, 'BoxR_curve.png')))

print("\n📊 PRECISION-RECALL CURVE")
print("-"*70)
display(Image(filename=os.path.join(results_path, 'BoxPR_curve.png')))

# 4. ПРИМЕРЫ ВАЛИДАЦИИ (первые 3 батча)
for i in range(3):
    print(f"\n🖼️ ВАЛИДАЦИОННЫЙ БАТЧ {i} - ПРЕДСКАЗАНИЯ")
    print("-"*70)
    display(Image(filename=os.path.join(results_path, f'val_batch{i}_pred.jpg')))

    print(f"\n🏷️ ВАЛИДАЦИОННЫЙ БАТЧ {i} - GROUND TRUTH")
    print("-"*70)
    display(Image(filename=os.path.join(results_path, f'val_batch{i}_labels.jpg')))

# 5. CSV С ДЕТАЛЬНЫМИ МЕТРИКАМИ
print("\n" + "="*70)
print("📋 ДЕТАЛЬНЫЕ МЕТРИКИ ИЗ CSV")
print("="*70)

csv_path = os.path.join(results_path, 'results.csv')
if os.path.exists(csv_path):
    df = pd.read_csv(csv_path)

    print("\n📊 Последние 10 эпох:")
    print(df.tail(10).to_string(index=False))

    print("\n\n📈 Лучшие результаты:")
    print(f"   🏆 Лучший mAP50: {df['metrics/mAP50(B)'].max():.4f} (epoch {df['metrics/mAP50(B)'].idxmax()})")
    print(f"   🏆 Лучший mAP50-95: {df['metrics/mAP50-95(B)'].max():.4f} (epoch {df['metrics/mAP50-95(B)'].idxmax()})")
    print(f"   🏆 Минимальный box_loss: {df['train/box_loss'].min():.4f} (epoch {df['train/box_loss'].idxmin()})")
    print(f"   🏆 Минимальный cls_loss: {df['train/cls_loss'].min():.4f} (epoch {df['train/cls_loss'].idxmin()})")

    print("\n\n📉 Динамика основных метрик:")
    key_epochs = [0, 5, 10, 15, 20, 25, 29]  # ключевые эпохи
    cols_to_show = ['epoch', 'train/box_loss', 'train/cls_loss', 'metrics/mAP50(B)', 'metrics/mAP50-95(B)']
    print(df.iloc[key_epochs][cols_to_show].to_string(index=False))
else:
    print("❌ CSV файл не найден")

print("\n" + "="*70)
print("✅ ВИЗУАЛИЗАЦИЯ ЗАВЕРШЕНА")
print("="*70)
# Out:
# ======================================================================
# 📊 ПОЛНАЯ ВИЗУАЛИЗАЦИЯ РЕЗУЛЬТАТОВ ОБУЧЕНИЯ
# ======================================================================
#
# 📈 ГРАФИКИ МЕТРИК ОБУЧЕНИЯ (loss, mAP, precision, recall)
# ----------------------------------------------------------------------
# 🎯 CONFUSION MATRIX
# ----------------------------------------------------------------------
# 🎯 NORMALIZED CONFUSION MATRIX
# ----------------------------------------------------------------------
# 📊 F1-CONFIDENCE CURVE
# ----------------------------------------------------------------------
# 📊 PRECISION-CONFIDENCE CURVE
# ----------------------------------------------------------------------
# 📊 RECALL-CONFIDENCE CURVE
# ----------------------------------------------------------------------
# 📊 PRECISION-RECALL CURVE
# ----------------------------------------------------------------------
# 🖼️ ВАЛИДАЦИОННЫЙ БАТЧ 0 - ПРЕДСКАЗАНИЯ
# ----------------------------------------------------------------------
# 🏷️ ВАЛИДАЦИОННЫЙ БАТЧ 0 - GROUND TRUTH
# ----------------------------------------------------------------------
# 🖼️ ВАЛИДАЦИОННЫЙ БАТЧ 1 - ПРЕДСКАЗАНИЯ
# ----------------------------------------------------------------------
# 🏷️ ВАЛИДАЦИОННЫЙ БАТЧ 1 - GROUND TRUTH
# ----------------------------------------------------------------------
# 🖼️ ВАЛИДАЦИОННЫЙ БАТЧ 2 - ПРЕДСКАЗАНИЯ
# ----------------------------------------------------------------------
# 🏷️ ВАЛИДАЦИОННЫЙ БАТЧ 2 - GROUND TRUTH
# ----------------------------------------------------------------------
# ======================================================================
# 📋 ДЕТАЛЬНЫЕ МЕТРИКИ ИЗ CSV
# ======================================================================
#
# 📊 Последние 10 эпох:
#  epoch    time  train/box_loss  train/cls_loss  train/dfl_loss  metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)  metrics/mAP50-95(B)  val/box_loss  val/cls_loss  val/dfl_loss   lr/pg0   lr/pg1   lr/pg2
#     91 5102.60         0.37049         0.24263         0.88422               0.94317            0.90998           0.96187              0.82408       0.58931       0.36158       1.06741 0.000050 0.000050 0.000050
#     92 5159.28         0.36994         0.24699         0.88347               0.93985            0.91537           0.96653              0.82819       0.59669       0.35621       1.07024 0.000045 0.000045 0.000045
#     93 5220.57         0.36049         0.23130         0.87118               0.91918            0.94167           0.97119              0.82497       0.59338       0.35315       1.07118 0.000040 0.000040 0.000040
#     94 5266.51         0.36264         0.23518         0.86389               0.94921            0.91605           0.97109              0.82837       0.59257       0.34993       1.07055 0.000035 0.000035 0.000035
#     95 5321.17         0.36846         0.24036         0.86177               0.91944            0.94105           0.96989              0.83133       0.58905       0.34697       1.06810 0.000030 0.000030 0.000030
#     96 5386.25         0.33939         0.22639         0.86675               0.91723            0.94255           0.97120              0.82974       0.58751       0.34462       1.06598 0.000025 0.000025 0.000025
#     97 5437.95         0.34575         0.22963         0.86650               0.91792            0.94632           0.97474              0.83345       0.58470       0.34118       1.06487 0.000020 0.000020 0.000020
#     98 5500.96         0.32525         0.22114         0.85026               0.90841            0.94396           0.97487              0.83458       0.58240       0.34079       1.06421 0.000015 0.000015 0.000015
#     99 5562.20         0.34304         0.22431         0.85373               0.91607            0.93802           0.97031              0.82707       0.58203       0.34177       1.06440 0.000010 0.000010 0.000010
#    100 5608.97         0.32886         0.22746         0.85957               0.91795            0.93642           0.97466              0.83142       0.58166       0.33871       1.06274 0.000005 0.000005 0.000005
#
#
# 📈 Лучшие результаты:
#    🏆 Лучший mAP50: 0.9749 (epoch 97)
#    🏆 Лучший mAP50-95: 0.8346 (epoch 97)
#    🏆 Минимальный box_loss: 0.3252 (epoch 97)
#    🏆 Минимальный cls_loss: 0.2211 (epoch 97)
#
#
# 📉 Динамика основных метрик:
#  epoch  train/box_loss  train/cls_loss  metrics/mAP50(B)  metrics/mAP50-95(B)
#      1         1.40774         3.23256           0.46706              0.34246
#      6         0.88124         1.30849           0.56591              0.41351
#     11         0.77159         0.87754           0.82485              0.61324
#     16         0.69618         0.67773           0.83766              0.64515
#     21         0.65815         0.64817           0.87548              0.67062
#     26         0.63532         0.54718           0.93861              0.70708
#     30         0.58194         0.50218           0.93511              0.73598
#
# ======================================================================
# ✅ ВИЗУАЛИЗАЦИЯ ЗАВЕРШЕНА
# ======================================================================
